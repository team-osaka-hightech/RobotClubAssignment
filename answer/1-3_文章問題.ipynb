# %% [markdown]
# ## 1-3.文章問題

# %%
distance = (3+4)*2
speed = 1

time = distance / speed

print("点Pが1周するのにかかる時間は", time, "[秒]です") # 14.0s
# Out:
# 点Pが1周するのにかかる時間は 14.0 [秒]です

# %%
R = 8.92 * 0.001 # [Ω/m]
x = 100 # [m]
i = 10 # [A]

def f(x):
    return R * x

print("(1)", x, "[m]の導線の抵抗は", f(x), "[Ω]です") # 0.892[Ω]

def g(i, r):
    return i**2 * r

print("(2)導線を流れる電流が", i,"[A]，", x, "[m]の導線の電力損失は", g(i, f(x)), "[W]です") # 89.2[W]
# Out:
# (1) 100 [m]の導線の抵抗は 0.8920000000000001 [Ω]です
# (2)導線を流れる電流が 10 [A]， 100 [m]の導線の電力損失は 89.20000000000002 [W]です

# %% [markdown]
# ## 課題

# %%
# 課題1

x = 20

def f1(x):
    if x <= 5:
        return 150 * x
    else:
        return 180 * 5 + 150 * (x - 5)


print("Aさんは", x, "[分]で", f1(x), "[m]進みました。")
# Out:
# Aさんは 20 [分]で 3150 [m]進みました。

# %%
# 課題2

a = 4
b = 256

def f2(a, b):
    count = 0
    while(a < b):
        a *= 2
        count += 1
        
    return count * 5

print(f2(a, b), "[分]待てばよいです。")
# Out:
# 30 [分]待てばよいです。

# %%
# 課題3

L = 123
l = 45

def f3(L, l):
    #直線と平行な長方形の辺の長さはL+lです。図にすると分かりやすいです。

    return L * (L+l)

print("長方形の面積は", f3(L, l), "[cm^2]です。")
# Out:
# 長方形の面積は 20664 [cm^2]です。
